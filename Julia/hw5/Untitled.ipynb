# %% [markdown]
# # HW5 in Julia Attempt

# %%
using MAT
# Out:
# ┌ Info: Precompiling MAT [23992714-dd62-5051-b70f-ba57cb901cac]
# └ @ Base loading.jl:1192

# %%
y = matread("hwk5.mat")["thousand_vectors_y"]
# Out:
# 16×1000 Array{Complex{Float64},2}:
#      1.03556-0.369888im     0.605412+0.296202im  …  -0.954615-0.828907im
#     0.055851+0.284052im    -0.380608-0.263545im      0.308522-0.380113im
#      1.42653-0.957157im    -0.266424+1.06246im         1.4614-0.0825003im
#   -0.0431922+0.853367im     0.581603-0.837975im     -0.400007+0.857038im
#     0.691826-0.456367im     -1.86654-0.505753im      0.572528-0.412502im
#      -1.4373+0.752755im    -0.182395+0.327926im  …  -0.150118-0.220156im
#   -0.0384649-0.0593185im    -0.37112+0.660321im     -0.563324-0.141988im
#    -0.794771-0.658077im       0.2197+0.825517im       1.94945-0.0176854im
#    -0.427481-0.959441im   -0.0942341-1.25784im       0.414156-0.736641im
#  -0.00325306-0.5725im       0.574496-0.861738im     -0.476957-1.33811im
#     -1.19485+0.719475im     0.415892-1.14003im   …   -1.53325+0.569265im
#      1.85913+0.964766im     0.633516-0.433433im     -0.059623+0.181456im
# ...

# %%
θ = 20
Δϕ = π*sind(θ)
# Out:
# 1.074487969651649

# %%
arr = collect(1:16)
s =  exp.(-im .* arr .* Δϕ)
# Out:
# 16-element Array{Complex{Float64},1}:
#   0.47618255771067436 - 0.8793464457948984im
#   -0.5465003434642405 - 0.8374588793448112im
#   -0.9966504203918025 + 0.08177982350704366im
#  -0.40267474918693424 + 0.9153431303982347im
#    0.6131570364051254 + 0.7899610425248094im
#    0.9866241209343136 - 0.16301179095572496im
#    0.3264693584059692 - 0.9452077856333997im
#   -0.6757060927344791 - 0.7371711309061848im
#   -0.9699882694039498 + 0.24315171646264505im
#  -0.24807689741376743 + 0.9687403434200308im
#    0.7337284863651171 + 0.6794427925118892im
#    0.9468543120188141 - 0.3216627299072405im
#    0.1680225297878833 - 0.9857831554067455im
#   -0.7868355160439896 - 0.6171627586721258im
#   -0.9173772268427337 + 0.39801887351020876im
#  -0.08684255248300692 + 0.9962220490825507im

# %%
(s'y[:,1:50])'
# Out:
# 50-element Array{Complex{Float64},1}:
#  -0.48967817807668257 - 6.019034588128306im
#   -3.7593557066837824 - 1.113845109275896im
#    -4.447651707005789 - 0.20793770367107411im
#   -0.3511611465338359 - 1.9888704540636897im
#     3.205711532658973 + 4.434643629576198im
#    0.9193186260843739 + 2.319739966878405im
#     3.886719724737419 - 1.8656785929883433im
#    2.3614938125963576 + 1.962323249624907im
#  -0.03383449989298204 + 0.128019308058001im
#   -2.7882782507568815 + 1.634008954762215im
#    1.7134893643760811 - 2.3890919189067574im
#   -3.3295694356219703 + 0.9973270099969258im
#     5.381588689995266 + 1.8907395612532316im
#                       ⋮
#    3.0826687104646835 + 2.0212447002865472im
#     7.256112470476836 - 7.119297269281401im
#    -2.644809073067406 - 4.591847188453831im
#     2.025757506328193 + 3.8078422157474208im
#     2.700784588222058 - 4.551386467178564im
#   -0.8916084927795183 + 3.1403349734122488im
#    0.4185731642898164 - 0.02152559400909171im
# ...

# %%
using Pkg

# %%
Pkg.add("PlotThemes")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [ccf2f8ad] + PlotThemes v0.3.0
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
using Plots
theme(:solarized_light)
plotly()
# Out:
# Plots.PlotlyBackend()

# %%
decvar = (s'y)' / 16
scatter(real(decvar), imag(decvar))
# Out:
#     <div id="cfee96e7-66e9-446b-b97a-e8457dc933de" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('cfee96e7-66e9-446b-b97a-e8457dc933de');
# ...
