# %%
using Statistics

# %%
using Pkg
Pkg.add("Plots")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#  Installed Showoff ─────── v0.2.1
#  Installed Measures ────── v0.3.0
#  Installed Contour ─────── v0.5.1
#  Installed PlotUtils ───── v0.5.5
#  Installed PoissonRandom ─ v0.3.1
#  Installed PlotThemes ──── v0.3.0
#  Installed GR ──────────── v0.37.0
#  Installed Plots ───────── v0.22.5
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [91a5bcdd] + Plots v0.22.5
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [d38c429a] + Contour v0.5.1
#   [28b8d3ca] + GR v0.37.0
#   [442fdcdd] + Measures v0.3.0
#   [ccf2f8ad] + PlotThemes v0.3.0
#   [995b91a9] + PlotUtils v0.5.5
#   [91a5bcdd] + Plots v0.22.5
#   [e409e4f3] ↑ PoissonRandom v0.3.0 ⇒ v0.3.1
#   [992d4aef] + Showoff v0.2.1
#   Building GR ───→ `~/.julia/packages/GR/shnUy/deps/build.log`
#   Building Plots → `~/.julia/packages/Plots/qh1wV/deps/build.log`

# %%
Pkg.add("PyPlot")
# Out:
#  Resolving package versions...
#  Installed PyPlot ─────── v2.7.0
#  Installed LaTeXStrings ─ v1.0.3
#  Installed PyCall ─────── v1.18.5
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [d330b81b] + PyPlot v2.7.0
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [b964fa9f] + LaTeXStrings v1.0.3
#   [438e738f] + PyCall v1.18.5
#   [d330b81b] + PyPlot v2.7.0
#   Building PyCall → `~/.julia/packages/PyCall/0jMpb/deps/build.log`

# %%
using Plots

# %%
pyplot()
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1192
# Plots.PyPlotBackend()

# %%
plot(rand(5,5), linewidth=3, title="Random Normal Vector")

# %%
X = randn(8, 1)
# Out:
# 8×1 Array{Float64,2}:
#   1.2896830307958598
#  -0.35625679709939795
#   0.8654295937613347
#  -2.213435669052383
#  -0.041232312683327076
#  -0.9438747245499008
#   0.875657434424123
#  -1.2044349743787588

# %%
x̄ = mean(X)
# Out:
# -0.21605805234780623

# %%
σ = std(X)
# Out:
# 1.2056449110947896

# %%
plot(X)
# Out:
# UndefVarError: plot not defined
#
# Stacktrace:
#  [1] top-level scope at In[7]:1
